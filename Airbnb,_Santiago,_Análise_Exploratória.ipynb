# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedrovalad/Pedro_Valadares_DS/blob/main/Airbnb%2C_Santiago%2C_An%C3%A1lise_Explorat%C3%B3ria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 4.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---
#
# # Análise dos Dados do Airbnb - *Santiago, Chile*
#
# O [Airbnb](https://www.airbnb.com.br/) já é considerado como sendo a **maior empresa hoteleira da atualidade**. Ah, o detalhe é que ele **não possui nenhum hotel**!
#
# Conectando pessoas que querem viajar (e se hospedar) com anfitriões que querem alugar seus imóveis de maneira prática, o Airbnb fornece uma plataforma inovadora para tornar essa hospedagem alternativa.
#
# No final de 2018, a Startup fundada 10 anos atrás, já havia **hospedado mais de 300 milhões** de pessoas ao redor de todo o mundo, desafiando as redes hoteleiras tradicionais.
#
# Uma das iniciativas do Airbnb é disponibilizar dados do site, para algumas das principais cidades do mundo. Por meio do portal [Inside Airbnb](http://insideairbnb.com/get-the-data.html), é possível baixar uma grande quantidade de dados para desenvolver projetos e soluções de *Data Science*.
#
# <center><img alt="Analisando Airbnb" width="10%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg"></center>
#
# **Neste *notebook*, iremos analisar os dados referentes à cidade Santiago no Chile, e ver quais insights podem ser extraídos a partir de dados brutos.**

# %% [markdown]
# ## Obtenção dos Dados

# %%
# importar os pacotes necessarios
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# importar o arquivo listings.csv para um DataFrame
df = pd.read_csv('https://data.insideairbnb.com/chile/rm/santiago/2023-12-26/visualisations/listings.csv')

# %% [markdown]
# ## Análise dos Dados

# %% [markdown]
# **Dicionário das variáveis**
#
# * id - número de id gerado para identificar o imóvel
# * name - nome da propriedade anunciada
# * host_id - número de id do proprietário (anfitrião) da propriedade
# * host_name - Nome do anfitrião
# * neighbourhood_group - esta coluna não contém nenhum valor válido
# * neighbourhood - nome do bairro
# * latitude - coordenada da latitude da propriedade
# * longitude - coordenada da longitude da propriedade
# * room_type - informa o tipo de quarto que é oferecido
# * price - preço para alugar o imóvel
# * minimum_nights - quantidade mínima de noites para reservar
# * number_of_reviews - número de reviews que a propriedade possui
# * last_review - data do último review
# * reviews_per_month - quantidade de reviews por mês
# * calculated_host_listings_count - quantidade de imóveis do mesmo anfitrião
# * availability_365 - número de dias de disponibilidade dentro de 365 dias
# * license — coluna vazia.
# * number_of_reviews_ltm — números de reviews (avaliações) nos últimos 12 meses.

# %%
# mostrar as 5 primeiras entradas
df.head(30)
# Out:
#         id                                               name   host_id  \
# 0    49392        Rental unit in Santiago · 1 bedroom · 1 bed    224592
# 1    52811  Rental unit in Providencia · ★4.42 · 1 bedroom...    244792
# 2   513333  Home in Santiago · ★4.86 · 2 bedrooms · 1 bed ...  55685236
# 3   529207    Home in Santiago · 1 bedroom · 7 beds · 6 baths   2294459
# 4    53494  Rental unit in Santiago · ★4.76 · 2 bedrooms ·...    249097
# 5   533042  Rental unit in Santiago · ★4.56 · 1 bedroom · ...   2619406
# 6    65058  Rental unit in Santiago · 1 bedroom · 1 bed · ...    318016
# 7   533257  Rental unit in Santiago · 1 bedroom · 1 bed · ...   2620569
# 8    73752  Rental unit in Santiago · 1 bedroom · 1 bed · ...    374124
# 9   558026  Rental unit in Santiago · ★4.95 · 2 bedrooms ·...   2743887
# 10   80482  Home in Santiago · 1 bedroom · 1 bed · 1 share...    154527
# 11  559852  Rental unit in Santiago · ★4.25 · 2 bedrooms ·...   2752180
# 12   88944  Condo in Providencia, Santiago · ★4.72 · 1 bed...    485358
# 13  564038  Rental unit in Santiago · 1 bedroom · 2 beds ·...   2773531
# 14   90694  Rental unit in Santiago · ★4.72 · 1 bedroom · ...    491253
# 15  583154        Rental unit in Santiago · 1 bedroom · 1 bed   2872968
# 16   90769  Rental unit in Santiago · ★5.0 · 1 bedroom · 1...    491253
# 17   95139    Home in Santiago · 1 bedroom · 3 beds · 2 baths    506998
# 18  600739  Rental unit in Santiago · ★4.36 · 2 bedrooms ·...   2752180
# 19  600741  Rental unit in Santiago · ★4.33 · 1 bedroom · ...   2752180
# 20   96722  Rental unit in Santiago · 1 bedroom · 2 beds ·...    513040
# 21  100057        Rental unit in Santiago · 1 bedroom · 1 bed    526328
# 22  609532  Rental unit in Santiago · 1 bedroom · 1 bed · ...   3022172
# 23  106795  Rental unit in Santiago · 1 bedroom · 1 bed · ...    552381
# 24  622498  Rental unit in Santiago · ★4.92 · 1 bedroom · ...   3085810
# 25  643936  Rental unit in Santiago · 1 bedroom · 2 beds ·...   3022172
# 26  643967  Rental unit in Santiago · 1 bedroom · 1 bed · ...   3022172
# 27  116494  Rental unit in Santiago · 1 bedroom · 1 bed · ...    588476
# 28  119688  Rental unit in Santiago · 1 bedroom · 3 beds ·...    603746
# 29  656930  Home in Santiago · ★4.86 · 1 bedroom · 12 beds...    619256
#
#           host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0             Maria                  NaN   Providencia -33.43277  -70.59892
# 1          Cristián                  NaN   Providencia -33.42959  -70.61880
# 2        María José                  NaN   Providencia -33.42932  -70.59085
# 3          Cristian                  NaN     Peñalolén -33.47754  -70.51952
# 4           Paulina                  NaN  Lo Barnechea -33.34521  -70.29543
# 5          Cristian                  NaN   Providencia -33.43037  -70.61789
# 6          Patricio                  NaN      Recoleta -33.43049  -70.64079
# 7           Jessica                  NaN      Santiago -33.43673  -70.64871
# 8   Daniela&Ricardo                  NaN      Santiago -33.43865  -70.64241
# 9            Marcia                  NaN   Providencia -33.43451  -70.62698
# 10       Jacqueline                  NaN    La Florida -33.51922  -70.59152
# 11           Marcos                  NaN   Providencia -33.42662  -70.61570
# 12         Macarena                  NaN   Providencia -33.42141  -70.60832
# 13            Betty                  NaN      Santiago -33.43835  -70.64545
# 14           Hector                  NaN   Providencia -33.42629  -70.61866
# 15            Jaime                  NaN      Santiago -33.45472  -70.63441
# 16           Hector                  NaN   Providencia -33.42864  -70.62178
# 17           Rafael                  NaN      Santiago -33.43657  -70.67851
# 18           Marcos                  NaN   Providencia -33.42465  -70.61568
# 19           Marcos                  NaN   Providencia -33.42681  -70.61578
# 20             Elby                  NaN    Las Condes -33.42360  -70.58372
# 21         Fernando                  NaN      Santiago -33.43297  -70.65815
# 22           Andrea                  NaN      Santiago -33.43786  -70.64830
# 23             Nora                  NaN      Santiago -33.43943  -70.65591
# 24      Luis Hernan                  NaN    Las Condes -33.41263  -70.58843
# 25           Andrea                  NaN      Santiago -33.43752  -70.64882
# 26           Andrea                  NaN      Santiago -33.43610  -70.64711
# 27          Antonio                  NaN      Santiago -33.43814  -70.64508
# 28            Marco                  NaN   Providencia -33.42942  -70.60583
# 29          Rodrigo                  NaN   Providencia -33.41902  -70.61178
#
#           room_type     price  minimum_nights  number_of_reviews last_review  \
# 0      Private room   47300.0               3                  0         NaN
# 1   Entire home/apt   48193.0               1                 45  2021-11-04
# 2      Private room   15000.0               1                 70  2019-11-03
# 3      Private room  533814.0               5                  0         NaN
# 4   Entire home/apt  149999.0               2                 37  2021-05-22
# 5   Entire home/apt   38884.0               3                170  2023-12-04
# 6      Private room   53548.0               2                  0         NaN
# 7      Private room   53356.0               2                  0         NaN
# 8      Private room   71397.0               3                  0         NaN
# 9   Entire home/apt   37895.0               2                 81  2023-12-12
# 10     Private room   23619.0               2                  0         NaN
# 11  Entire home/apt   98171.0               2                 12  2019-07-14
# 12  Entire home/apt   36460.0               3                204  2023-12-13
# 13  Entire home/apt   75859.0               2                  1  2013-11-27
# 14  Entire home/apt   49999.0               3                 71  2023-08-26
# 15     Private room   44623.0               1                  0         NaN
# 16  Entire home/apt   49999.0               4                 11  2013-03-08
# 17     Private room   63365.0               7                  0         NaN
# 18  Entire home/apt   98171.0               2                 22  2018-07-18
# 19  Entire home/apt   62472.0               2                  9  2017-02-28
# 20     Private room   53548.0               1                  0         NaN
# 21     Private room   71397.0              14                  2  2012-02-13
# 22     Private room   71397.0               1                  0         NaN
# 23  Entire home/apt   71397.0               1                  0         NaN
# 24  Entire home/apt   98171.0               4                 27  2021-03-20
# 25     Private room   71397.0               3                  0         NaN
# 26     Private room   71397.0               1                  0         NaN
# 27     Private room   53548.0               1                  0         NaN
# 28     Private room   40161.0               1                  0         NaN
# 29     Private room   35000.0               1                 14  2023-11-10
#
#     reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                 NaN                               1               178
# 1                0.28                               3                86
# 2                0.54                               1               239
# 3                 NaN                               1               365
# 4                0.41                               1               365
# 5                1.98                               1               156
# 6                 NaN                               1                 0
# 7                 NaN                               1               365
# 8                 NaN                               1                 0
# 9                0.76                               1               283
# 10                NaN                               1                 0
# 11               0.12                               8               360
# 12               1.37                               1               155
# 13               0.01                               1                 0
# 14               0.46                               2               358
# 15                NaN                               1                 0
# 16               0.07                               2               363
# 17                NaN                               1                 0
# 18               0.21                               8               359
# 19               0.09                               8               265
# 20                NaN                               1                 0
# 21               0.01                               1                 0
# 22                NaN                               3                 0
# 23                NaN                               1                 0
# 24               0.20                               3               144
# 25                NaN                               3                 0
# 26                NaN                               3                 0
# 27                NaN                               1                 0
# 28                NaN                               1                 0
# 29               0.45                               6               365
#
#     number_of_reviews_ltm license
# 0                       0     NaN
# 1                       0     NaN
# 2                       0     NaN
# 3                       0     NaN
# 4                       0     NaN
# 5                      34     NaN
# 6                       0     NaN
# 7                       0     NaN
# 8                       0     NaN
# 9                      44     NaN
# 10                      0     NaN
# 11                      0     NaN
# 12                     26     NaN
# 13                      0     NaN
# 14                      5     NaN
# 15                      0     NaN
# 16                      0     NaN
# 17                      0     NaN
# 18                      0     NaN
# 19                      0     NaN
# 20                      0     NaN
# 21                      0     NaN
# 22                      0     NaN
# 23                      0     NaN
# 24                      0     NaN
# 25                      0     NaN
# 26                      0     NaN
# 27                      0     NaN
# 28                      0     NaN
# 29                      5     NaN

# %% [markdown]
# ### **Q1. Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui? Quais os tipos das variáveis?**

# %%
# identificar o volume de dados do DataFrame
print('Entradas: \t{}'.format(df.shape[0]))
print('Variáveis: \t{}'.format(df.shape[1]))

# verificar as 5 primeiras entradas do dataset
# Out:
# Entradas: 	12284
# Variáveis: 	18

# %% [markdown]
# #### Q1.1. Convertendo os valores da coluna "Price" de pesos para reais.
#
# Para trabalharmos com parâmetros mais relacionadas à nossa realidade, os preços da coluna "Price" foram convertidos de peso chileno para reais. Isso foi feito utilizando a taxa de câmbio do dia 17 de abril de 2024.

# %%
#Para melhorar a análise dos valores da coluna "Price", vamos converter os valores para reais, utilizando a taxa de câmbio de 17/04/2024

taxa_de_cambio = 187  # 187 pesos = 1 real

# Substituindo a coluna 'price' com os valores convertidos para reais
df['price'] = df['price'] / taxa_de_cambio

# %% [markdown]
# ### **Q2. Qual a porcentagem de valores ausentes no *dataset*?**
#
# A análise de valores ausentes é fundamental para decidirmos com quais variáveis vamos trabalhar na análise exploratória. Coluna com alto número de valores null podem ser desconsideradas em um primeiro momento.

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum()/df.shape[0]).sort_values(ascending=False)
# Out:
# neighbourhood_group               1.000000
# license                           0.981358
# reviews_per_month                 0.242511
# last_review                       0.242511
# price                             0.043634
# host_name                         0.000163
# neighbourhood                     0.000000
# latitude                          0.000000
# longitude                         0.000000
# room_type                         0.000000
# name                              0.000000
# minimum_nights                    0.000000
# number_of_reviews                 0.000000
# host_id                           0.000000
# calculated_host_listings_count    0.000000
# availability_365                  0.000000
# number_of_reviews_ltm             0.000000
# id                                0.000000
# dtype: float64

# %% [markdown]
# ### **Q3. Qual o tipo de distribuição das variáveis?**
# A análise dos histogramas nos permite entender melhor quais variáveis apresentam outliers, que podem estar desbalanceando a distribuição e também prejudicando a análise exploratória.

# %%
# plotar o histograma das variáveis numéricas
df.hist(bins = 15, figsize =(15,10))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'host_id'}>,
#         <Axes: title={'center': 'neighbourhood_group'}>],
#        [<Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'price'}>],
#        [<Axes: title={'center': 'minimum_nights'}>,
#         <Axes: title={'center': 'number_of_reviews'}>,
#         <Axes: title={'center': 'reviews_per_month'}>],
#        [<Axes: title={'center': 'calculated_host_listings_count'}>,
#         <Axes: title={'center': 'availability_365'}>,
#         <Axes: title={'center': 'number_of_reviews_ltm'}>]], dtype=object)

# %% [markdown]
# ### **Q4.Há outliers presentes?**
#
# Em uma primeira análise da variáveis numéricas, é possível ver uma discrepância grande entre os valores da média e da mediana, assim como uma diferença elevada entre o valor máximo e o valor do terceiro quartil.
#
# Essas duas constatações nos permitem deduzir que há outliers no nosso conjunto de dados.
#
# Os boxplots da variáveis "price" e "minimum_nights" confirmam isso. Por isso, decidiu-se, em um primeiro momento, por criar uma cópia do Data Frame com a remação dos outliers.
#
# O intervalo escolhido para remoção foi feito de forma arbitrária, para que excluíssemos menos de 1% das nossas entradas em cada uma das variáveis.
#
# Note que, com a retirada de parte dos outliers, a distribuição nos histogramas fica bem mais interessante.

# %%
# ver a média da coluna `price``
df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].describe()
# Out:
#                price  minimum_nights  number_of_reviews  reviews_per_month  \
# count   11748.000000    12284.000000       12284.000000        9305.000000
# mean      486.232185        6.701075          25.571638           1.487830
# std      4465.407963       37.112770          52.609307           1.756415
# min        41.069519        1.000000           0.000000           0.010000
# 25%       160.427807        1.000000           1.000000           0.290000
# 50%       226.788770        2.000000           6.000000           0.890000
# 75%       340.898396        3.000000          26.000000           2.050000
# max    286350.775401     1124.000000        1118.000000          21.130000
#
#        calculated_host_listings_count  availability_365
# count                    12284.000000      12284.000000
# mean                         5.557473        206.266281
# std                         13.610707        143.097168
# min                          1.000000          0.000000
# 25%                          1.000000         63.000000
# 50%                          1.000000        256.000000
# 75%                          4.000000        355.000000
# max                        120.000000        365.000000

# %% [markdown]
# ### Boxplot para "minimum_nights

# %%
#minimum_nights

df.minimum_nights.plot(kind = "box", vert = False, figsize = (15,3))
plt.show()

# ver quantidade de valores acima de 90 dias para minimum_nights
print("minimum_nights: valores acima de 90:")
print("{} entradas".format(len(df[df.minimum_nights > 90])))
print("{:.4}%".format((len(df[df.minimum_nights > 90])/df.shape[0])*100))
# Out:
# minimum_nights: valores acima de 90:
# 105 entradas
# 0.8548%

# %% [markdown]
# ### Boxplot para "price"

# %%
#price
df.price.plot(kind = "box", vert = False, figsize = (15,3))
plt.show()

# ver quantidade de valores acima de 2700 para price
print("\nprice: valores acima de 2700")
print("{} entradas".format(len(df[df.price > 2700])))
print("{:.4f}%".format((len(df[df.price > 2700]) / df.shape[0])*100))
# Out:
# price: valores acima de 2700
# 110 entradas
# 0.8955%

# %% [markdown]
# ### Remoção de outliers

# %%
# remover os *outliers* em um novo DataFrame
df_clean = df.copy()
df_clean.drop(df_clean[df_clean.minimum_nights > 90].index, axis = 0, inplace = True)
df_clean.drop(df_clean[df_clean.price > 2700].index, axis = 0, inplace = True)

# remover `neighbourhood_group`, pois está vazio
df_clean.drop('neighbourhood_group', axis = 1, inplace = True)

# plotar o histograma para as variáveis numéricas
df_clean.hist(bins = 15, figsize = (15,10))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'host_id'}>,
#         <Axes: title={'center': 'latitude'}>],
#        [<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'minimum_nights'}>],
#        [<Axes: title={'center': 'number_of_reviews'}>,
#         <Axes: title={'center': 'reviews_per_month'}>,
#         <Axes: title={'center': 'calculated_host_listings_count'}>],
#        [<Axes: title={'center': 'availability_365'}>,
#         <Axes: title={'center': 'number_of_reviews_ltm'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### **Q4. Qual a correlação existente entre as variáveis**
#
# Com base na matriz de correlação abaixo, criamos um heatmap (mapa de calor), que ilustra a força e a direção das relações lineares entre cada par de variáveis. A escala de cores vai de azul (correlações positivas) para vermelho (correlações negativas), com intensidades mais fortes indicando correlações mais fortes.
#
# Com base tanto na matriz de correlação quanto no mapa de calor, é possível observar que:
#
# **price (Preço) e reviews_per_month (Avaliações por Mês):**
#
# Existe uma correlação negativa moderada de -0.16, sugerindo que preços mais altos podem levar a menos avaliações por mês.
#
# **number_of_reviews (Número de Avaliações) e reviews_per_month (Avaliações por Mês):**
#
# Há uma correlação positiva forte de 0.48. Isso indica que propriedades com mais avaliações acumuladas tendem a receber mais avaliações mensais, o que é um comportamento esperado.
#
# **calculated_host_listings_count (Contagem de Anúncios do Anfitrião) e availability_365 (Disponibilidade Anual):**
#
# Uma correlação positiva fraca de 0.10 mostra que anfitriões com mais anúncios tendem a ter um pouco mais de disponibilidade durante o ano.
#
# **price (Preço) e minimum_nights (Noites Mínimas):**
#
# Com uma correlação quase nula de 0.01, parece não haver praticamente nenhuma relação linear entre o preço de uma acomodação e o número mínimo de noites.
#
# **minimum_nights (Noites Mínimas) e number_of_reviews (Número de Avaliações):**
#
# Uma correlação negativa fraca de -0.07 sugere que propriedades que exigem estadias mais longas podem ter ligeiramente menos avaliações.
# Observações Gerais:
#
# * As correlações mais fortes neste conjunto de dados estão entre number_of_reviews e reviews_per_month, o que é intuitivo, já que propriedades mais avaliadas teriam tendência a receber mais avaliações regularmente.
# * A maioria das outras variáveis apresenta correlações muito fracas entre si, indicando que não há relações lineares fortes entre elas.

# %%
# criar uma matriz de correlação
corr = df_clean[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].corr()
# mostrar a matriz de correlação
display(corr)
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000        0.014133          -0.075007
# minimum_nights                  0.014133        1.000000          -0.067226
# number_of_reviews              -0.075007       -0.067226           1.000000
# reviews_per_month              -0.157698       -0.161849           0.476442
# calculated_host_listings_count  0.034335       -0.071461           0.011731
# availability_365                0.074496       -0.027906          -0.025235
#
#                                 reviews_per_month  \
# price                                   -0.157698
# minimum_nights                          -0.161849
# number_of_reviews                        0.476442
# reviews_per_month                        1.000000
# calculated_host_listings_count           0.085656
# availability_365                        -0.050214
#
#                                 calculated_host_listings_count  \
# price                                                 0.034335
# minimum_nights                                       -0.071461
# number_of_reviews                                     0.011731
# reviews_per_month                                     0.085656
# calculated_host_listings_count                        1.000000
# availability_365                                      0.100787
#
#                                 availability_365
# price                                   0.074496
# minimum_nights                         -0.027906
# number_of_reviews                      -0.025235
# reviews_per_month                      -0.050214
# calculated_host_listings_count          0.100787
# availability_365                        1.000000

# %%
# plotar um heatmap a partir das correlações
sns.heatmap(corr, cmap = 'RdBu', fmt = '.2f', square = True, linecolor = 'white', annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### **Q5. Qual o tipo de imóvel mais alugado no Airbnb?**

# %%
# mostrar a quantidade de cada tipo de imóvel disponível
df_clean.room_type.value_counts()
# Out:
# room_type
# Entire home/apt    8228
# Private room       3636
# Shared room         163
# Hotel room           43
# Name: count, dtype: int64

# %%
# mostrar a porcentagem de cada tipo de imóvel disponível
df_clean.room_type.value_counts()/df_clean.shape[0]
# Out:
# room_type
# Entire home/apt    0.681690
# Private room       0.301243
# Shared room        0.013505
# Hotel room         0.003563
# Name: count, dtype: float64

# %% [markdown]
# ### **Q6. Qual a localidade mais cara do dataset?**

# %%
# ver preços por bairros, na média
df_clean.groupby(['neighbourhood']).price.mean().sort_values(ascending = False)[:10]
# Out:
# neighbourhood
# Lo Barnechea    1200.513289
# Vitacura         507.668127
# Las Condes       380.588821
# La Granja        373.763102
# Huechuraba       344.499674
# Pudahuel         329.023115
# Lo Espejo        295.213904
# Providencia      292.725094
# Quilicura        287.273470
# San Miguel       251.269276
# Name: price, dtype: float64

# %%
# ver quantidade de imóveis no La Granja
print("La Granja:",df_clean[df_clean.neighbourhood == "La Granja"].shape)

# ver quantidade de imóveis no Lo Espejo
print("Lo Espejo:",df_clean[df_clean.neighbourhood == "Lo Espejo"].shape)

# ver quantidade de imóveis no Providencia
print("Providencia:", df_clean[df_clean.neighbourhood == "Providencia"].shape)

# ver quantidade de imóveis no Las Condes
print("Las Condes:", df_clean[df_clean.neighbourhood == "Las Condes"].shape)
# Out:
# La Granja: (10, 17)
# Lo Espejo: (2, 17)
# Providencia: (2358, 17)
# Las Condes: (2070, 17)

# %%
# plotar os imóveis pela latitude-longitude
df_clean.plot(kind = 'scatter', x = 'longitude', y = 'latitude', alpha = 0.4, c=df_clean['price'], s=8,
              cmap=plt.get_cmap('jet'), figsize=(12,8))
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ### **Q7. Qual é a média do mínimo de noites para aluguel (minimum_nights)?**

# %%
# ver a média da coluna `minimum_nights``
df_clean.minimum_nights.mean()
# Out:
# 4.059817729908865

# %% [markdown]
# ### **Q8. Quais localidades tem mais imóveis para alugar?**

# %%
# Contagem de imóveis por bairro
imoveis_por_bairro = df_clean['neighbourhood'].value_counts()

# Calculando as porcentagens
porcentagens = (imoveis_por_bairro / imoveis_por_bairro.sum()) * 100

# Criando um DataFrame com as contagens e as porcentagens
df_bairros = pd.DataFrame({
    'Quantidade': imoveis_por_bairro,
    'Porcentagem': porcentagens
})

# Exibindo o DataFrame
print(df_bairros)
# Out:
#                      Quantidade  Porcentagem
# neighbourhood
# Santiago                   4105    34.009942
# Providencia                2358    19.536040
# Las Condes                 2070    17.149959
# Ñuñoa                       899     7.448219
# Lo Barnechea                660     5.468103
# Vitacura                    330     2.734051
# Recoleta                    251     2.079536
# Estación Central            209     1.731566
# San Miguel                  148     1.226181
# Macul                       145     1.201326
# La Florida                  126     1.043911
# La Reina                    124     1.027341
# Maipú                       104     0.861640
# Peñalolén                    82     0.679370
# San Joaquín                  68     0.563380
# Pudahuel                     63     0.521955
# Independencia                62     0.513670
# La Cisterna                  58     0.480530
# Huechuraba                   46     0.381110
# Quinta Normal                42     0.347970
# Quilicura                    37     0.306545
# Renca                        14     0.115990
# El Bosque                    12     0.099420
# Cerrillos                    12     0.099420
# Conchalí                     12     0.099420
# Lo Prado                     10     0.082850
# La Granja                    10     0.082850
# Pedro Aguirre Cerda           5     0.041425
# Cerro Navia                   4     0.033140
# Lo Espejo                     2     0.016570
# San Ramón                     2     0.016570

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Em uma análise exploratório superficial na base de dados do Airbnb para a cidade de Santiago, porém foi possível detectar a presença de outliers em algumas das variáveis.
#
# No que diz respeito à média de preços por bairros, é preciso observar que algumas das localidades que estão no top10 apresentam poucos imóveis disponíveis, em especial os bairros de La Granja e El Espejo.
#
# Outro ponto interessante é que três bairros (Santiago, Providência e Las Condes) concentram mais de 70% das entradas do dataset, o que pode indicar a necessidade de uma subdivisão em áreas nessas localidades para uma análise mais precisa, tendo em vista que pode haver uma variedade grande na qualidade e no tipo de imóveis em diferentes regiões desses bairros.
#
# No que diz respeito à análise de correlação, não se verificou relações lineares fortes entre a variáveis.
#
# Um ponto que talvez valha um aprofundamento é na correlação entre as variáveis price (Preço) e reviews_per_month (Avaliações por Mês).Existe uma correlação negativa moderada de -0.16, sugerindo que preços mais altos podem levar a menos avaliações por mês. Isso também pode indicar que preços mais altos levam a menos aluguéis e, consequentemente, menos avaliações.
#
# Por fim, lembra-se que este dataset é uma versão resumida, ideal apenas para uma abordagem inicial. Recomenda-se que seja usado, em uma próxima análise exploratória, o conjunto de dados completos, com uma quantidade maior de atributos disponíveis.
